# %%
import swimclub

# %%
swimclub.read_swim_data("Darius-13-100m-Fly.txt")
# Out:
# ('Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58')

# %%
data = swimclub.read_swim_data("Darius-13-100m-Fly.txt")

# %%
times = data[4]
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimmer, age, distance, stroke, times2, average  = data
times2
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
import os

# %%
swim_files = os.listdir(swimclub.FOLDER)

# %%
len(swim_files)
# Out:
# 61

# %%
print(swim_files)
# Out:
# ['Mike-15-100m-Back.txt', 'Abi-10-50m-Free.txt', 'Lizzie-14-100m-Free.txt', 'Ruth-13-100m-Free.txt', 'Mike-15-100m-Fly.txt', 'Ali-12-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Dave-17-100m-Free.txt', 'Abi-10-100m-Breast.txt', 'Owen-15-100m-Free.txt', 'Emma-13-100m-Free.txt', 'Katie-9-100m-Free.txt', 'Abi-10-50m-Back.txt', 'Erika-15-100m-Breast.txt', 'Maria-9-50m-Free.txt', 'Katie-9-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Abi-10-100m-Back.txt', 'Ruth-13-200m-Free.txt', 'Katie-9-50m-Breast.txt', 'Erika-15-100m-Free.txt', 'Blake-15-100m-Free.txt', 'Darius-13-100m-Fly.txt', 'Tasmin-15-200m-Breast.txt', 'Calvin-9-50m-Back.txt', 'Bill-18-200m-Back.txt', 'Darius-13-100m-Back.txt', 'Alison-14-100m-Breast.txt', 'Tasmin-15-100m-Free.txt', 'Blake-15-100m-Back.txt', 'Katie-9-50m-Fly.txt', 'Carl-15-100m-Back.txt', 'Calvin-9-50m-Fly.txt', '.DS_Store', 'Mike-15-200m-IM.txt', 'Aurora-13-50m-Free.txt', 'Katie-9-50m-Back.txt', 'Mike-15-200m-Free.txt', 'Darius-13-100m-Breast.txt', 'Ruth-13-100m-Back.txt', 'Mike-15-100m-Free.txt', 'Ali-12-100m-Back.txt', 'Tasmin-15-100m-Breast.txt', 'Tasmin-15-100m-Back.txt', 'Erika-15-200m-Breast.txt', 'Emma-13-100m-Breast.txt', 'Bill-18-100m-Back.txt', 'Hannah-13-100m-Back.txt', 'Ruth-13-400m-Free.txt', 'Katie-9-50m-Free.txt', 'Chris-17-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Darius-13-200m-IM.txt', 'Blake-15-100m-Fly.txt', 'Katie-9-100m-Back.txt', 'Dave-17-200m-Back.txt', 'Calvin-9-50m-Free.txt', 'Lizzie-14-100m-Back.txt', 'Abi-10-50m-Breast.txt', 'Elba-14-100m-Free.txt', 'Chris-17-100m-Breast.txt']

# %%
sorted(swim_files)
# Out:
# ['.DS_Store',
#  'Abi-10-100m-Back.txt',
#  'Abi-10-100m-Breast.txt',
#  'Abi-10-50m-Back.txt',
#  'Abi-10-50m-Breast.txt',
#  'Abi-10-50m-Free.txt',
#  'Ali-12-100m-Back.txt',
#  'Ali-12-100m-Free.txt',
#  'Alison-14-100m-Breast.txt',
#  'Alison-14-100m-Free.txt',
#  'Aurora-13-50m-Free.txt',
#  'Bill-18-100m-Back.txt',
#  'Bill-18-200m-Back.txt',
#  'Blake-15-100m-Back.txt',
#  'Blake-15-100m-Fly.txt',
#  'Blake-15-100m-Free.txt',
#  'Calvin-9-50m-Back.txt',
#  'Calvin-9-50m-Fly.txt',
#  'Calvin-9-50m-Free.txt',
#  'Carl-15-100m-Back.txt',
#  'Chris-17-100m-Back.txt',
#  'Chris-17-100m-Breast.txt',
#  'Darius-13-100m-Back.txt',
#  'Darius-13-100m-Breast.txt',
#  'Darius-13-100m-Fly.txt',
#  'Darius-13-200m-IM.txt',
#  'Dave-17-100m-Free.txt',
#  'Dave-17-200m-Back.txt',
#  'Elba-14-100m-Free.txt',
#  'Emma-13-100m-Breast.txt',
#  'Emma-13-100m-Free.txt',
#  'Erika-15-100m-Breast.txt',
#  'Erika-15-100m-Free.txt',
#  'Erika-15-200m-Breast.txt',
#  'Hannah-13-100m-Back.txt',
#  'Hannah-13-100m-Free.txt',
#  'Katie-9-100m-Back.txt',
#  'Katie-9-100m-Breast.txt',
#  'Katie-9-100m-Free.txt',
#  'Katie-9-50m-Back.txt',
#  'Katie-9-50m-Breast.txt',
#  'Katie-9-50m-Fly.txt',
#  'Katie-9-50m-Free.txt',
#  'Lizzie-14-100m-Back.txt',
#  'Lizzie-14-100m-Free.txt',
#  'Maria-9-50m-Free.txt',
#  'Mike-15-100m-Back.txt',
#  'Mike-15-100m-Fly.txt',
#  'Mike-15-100m-Free.txt',
#  'Mike-15-200m-Free.txt',
#  'Mike-15-200m-IM.txt',
#  'Owen-15-100m-Free.txt',
#  'Ruth-13-100m-Back.txt',
#  'Ruth-13-100m-Free.txt',
#  'Ruth-13-200m-Back.txt',
#  'Ruth-13-200m-Free.txt',
#  'Ruth-13-400m-Free.txt',
#  'Tasmin-15-100m-Back.txt',
#  'Tasmin-15-100m-Breast.txt',
#  'Tasmin-15-100m-Free.txt',
#  'Tasmin-15-200m-Breast.txt']

# %%
help(swim_files.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
swim_files.remove('.DS_Store')

# %%
len(swim_files)
# Out:
# 60

# %%
for n, s in enumerate(swim_files, 1):
    print (n, "Processando o Arquivo: ", s)
    swimclub.read_swim_data(s)
# Out:
# 1 Processando o Arquivo:  Mike-15-100m-Back.txt
# 2 Processando o Arquivo:  Abi-10-50m-Free.txt
# 3 Processando o Arquivo:  Lizzie-14-100m-Free.txt
# 4 Processando o Arquivo:  Ruth-13-100m-Free.txt
# 5 Processando o Arquivo:  Mike-15-100m-Fly.txt
# 6 Processando o Arquivo:  Ali-12-100m-Free.txt
# 7 Processando o Arquivo:  Ruth-13-200m-Back.txt
# 8 Processando o Arquivo:  Dave-17-100m-Free.txt
# 9 Processando o Arquivo:  Abi-10-100m-Breast.txt
# 10 Processando o Arquivo:  Owen-15-100m-Free.txt
# 11 Processando o Arquivo:  Emma-13-100m-Free.txt
# 12 Processando o Arquivo:  Katie-9-100m-Free.txt
# 13 Processando o Arquivo:  Abi-10-50m-Back.txt
# 14 Processando o Arquivo:  Erika-15-100m-Breast.txt
# 15 Processando o Arquivo:  Maria-9-50m-Free.txt
# 16 Processando o Arquivo:  Katie-9-100m-Breast.txt
# 17 Processando o Arquivo:  Alison-14-100m-Free.txt
# 18 Processando o Arquivo:  Abi-10-100m-Back.txt
# 19 Processando o Arquivo:  Ruth-13-200m-Free.txt
# 20 Processando o Arquivo:  Katie-9-50m-Breast.txt
# 21 Processando o Arquivo:  Erika-15-100m-Free.txt
# 22 Processando o Arquivo:  Blake-15-100m-Free.txt
# 23 Processando o Arquivo:  Darius-13-100m-Fly.txt
# 24 Processando o Arquivo:  Tasmin-15-200m-Breast.txt
# 25 Processando o Arquivo:  Calvin-9-50m-Back.txt
# 26 Processando o Arquivo:  Bill-18-200m-Back.txt
# 27 Processando o Arquivo:  Darius-13-100m-Back.txt
# 28 Processando o Arquivo:  Alison-14-100m-Breast.txt
# 29 Processando o Arquivo:  Tasmin-15-100m-Free.txt
# 30 Processando o Arquivo:  Blake-15-100m-Back.txt
# 31 Processando o Arquivo:  Katie-9-50m-Fly.txt
# 32 Processando o Arquivo:  Carl-15-100m-Back.txt
# 33 Processando o Arquivo:  Calvin-9-50m-Fly.txt
# 34 Processando o Arquivo:  Mike-15-200m-IM.txt
# 35 Processando o Arquivo:  Aurora-13-50m-Free.txt
# 36 Processando o Arquivo:  Katie-9-50m-Back.txt
# 37 Processando o Arquivo:  Mike-15-200m-Free.txt
# 38 Processando o Arquivo:  Darius-13-100m-Breast.txt
# 39 Processando o Arquivo:  Ruth-13-100m-Back.txt
# 40 Processando o Arquivo:  Mike-15-100m-Free.txt
# 41 Processando o Arquivo:  Ali-12-100m-Back.txt
# 42 Processando o Arquivo:  Tasmin-15-100m-Breast.txt
# 43 Processando o Arquivo:  Tasmin-15-100m-Back.txt
# 44 Processando o Arquivo:  Erika-15-200m-Breast.txt
# 45 Processando o Arquivo:  Emma-13-100m-Breast.txt
# 46 Processando o Arquivo:  Bill-18-100m-Back.txt
# 47 Processando o Arquivo:  Hannah-13-100m-Back.txt
# 48 Processando o Arquivo:  Ruth-13-400m-Free.txt
# 49 Processando o Arquivo:  Katie-9-50m-Free.txt
# 50 Processando o Arquivo:  Chris-17-100m-Back.txt
# 51 Processando o Arquivo:  Hannah-13-100m-Free.txt
# 52 Processando o Arquivo:  Darius-13-200m-IM.txt
# 53 Processando o Arquivo:  Blake-15-100m-Fly.txt
# 54 Processando o Arquivo:  Katie-9-100m-Back.txt
# 55 Processando o Arquivo:  Dave-17-200m-Back.txt
# 56 Processando o Arquivo:  Calvin-9-50m-Free.txt
# 57 Processando o Arquivo:  Lizzie-14-100m-Back.txt
# 58 Processando o Arquivo:  Abi-10-50m-Breast.txt
# 59 Processando o Arquivo:  Elba-14-100m-Free.txt
# 60 Processando o Arquivo:  Chris-17-100m-Breast.txt

# %%
for t in times:
    print(t)
# Out:
# 1:27.95
# 1:21.07
# 1:30.96
# 1:23.22
# 1:27.95
# 1:28.30

# %%
"ell" in "Hello"
# Out:
# True

# %%
"fell" in "Hello"
# Out:
# False

# %%
42 in ("Forty two", 42, "42")
# Out:
# True

# %%
"two" in ("Forty two", 42, "42") [0]
# Out:
# True

# %%
[1, 2, 3] in ['a','b', 'c', [1, 2, 3], 'd', 'e', 'f']
# Out:
# True

# %%
[1, 2] in ['a','b', 'c', [1, 2, 3], 'd', 'e', 'f']
# Out:
# False
